# %% [markdown]
# # ODS_project
# ### Optimization Methods for Recommender Systems
# #### Rebecca Esegio, Giacomo Filippin, Emma Lovato
# 2130576, Lovato Emma, emma.lovato@studenti.unipd.it
#
# 2144564, Rebecca Esegio, rebecca.esegio@studenti.unipd.it
#
# 2130958, Giacomo Filippin, giacomo.filippin@studenti.unipd.it

# %% [markdown]
# ## Understanding the Problem & Theoretical Foundations
# The goal is to implement and compare three variants of the Frank-Wolfe algorithm for a Matrix Completion problem, a key application in recommender systems.

# %% [markdown]
# ### The Matrix Completion Problem
#
# We want to recover a matrix $X \in \mathbb{R}^{m \times n}$ (e.g., user ratings for movies) from which we only observe a small subset of entries. The key assumption is that the original matrix is **low-rank**. The problem can be formulated as follows:
#
# $$
# \min_{X \in \mathbb{R}^{m \times n}} f(X) := \sum_{(i,j) \in J} (X_{ij} - U_{ij})^2 \quad \text{s.t.} \quad \text{rank}(X) \le \delta
# $$
#
# where $U$ is the matrix of observed ratings, $J$ is the set of known rating indices, and $\delta$ is the desired maximum rank. Since the rank constraint is non-convex and hard to handle, a convex relaxation is used, constraining the **nuclear norm** (the sum of the singular values) of the matrix:
#
# $$
# \min_{X \in \mathbb{R}^{m \times n}} f(X) := \sum_{(i,j) \in J} (X_{ij} - U_{ij})^2 \quad \text{s.t.} \quad \|X\|_* \le \tau
# $$

# %% [markdown]
# ### Objective Function:
#  $f(X)$ is a quadratic function, hence it is convex and differentiable. Its gradient is:
#     $$
#     \nabla f(X) = 2(X - U)_J
#     $$
#     where $(A)_J$ is a matrix that has the same values as $A$ on the indices $J$ and is zero elsewhere.
#
# ### Feasible Domain:
# The domain $C = \{X \in \mathbb{R}^{m \times n} : \|X\|_* \le \tau\}$ is the nuclear norm ball. It is a compact and convex set. Crucially, it is the convex hull of rank-1 matrices:
#     $$
#     C = \text{conv}\{\tau \mathbf{u}\mathbf{v}^T : \mathbf{u} \in \mathbb{R}^m, \mathbf{v} \in \mathbb{R}^n, \|\mathbf{u}\|_2 = \|\mathbf{v}\|_2 = 1\}
#     $$
#     These rank-1 elements, $\tau \mathbf{u}\mathbf{v}^T$, are the **atoms** of our domain.

# %% [markdown]
# ### Key Algorithm Components
#
# **a) Linear Minimization Oracle (LMO)**
#
#
# **b) Line Search for the Optimal Step $\gamma$**
#
# **c) Decaying Stepize**
#
# **d) Armijo Stepsize**

# %% [markdown]
# ### Understanding the Nuclear Norm Ball and Its Role in the Project
#
# The **nuclear norm ball** is a central concept in this project. It serves as the feasible set for our optimization problem and is the primary reason why the Frank-Wolfe algorithm is such an effective tool for Matrix Completion. This section explains what it is and why it's so important.
#
# #### 1. The Simple, Direct Definition
#
# Simply put, the nuclear norm ball is a "container" for matrices. It is defined by two components:
#
# * **The Nuclear Norm ($||X||_*$):** This is the sum of all the singular values of a matrix $X$. The singular values ($\sigma_i$) can be thought of as measuring the magnitude of the matrix in different principal directions.
#     $$
#     \|X\|_* = \sum_i \sigma_i(X)
#     $$
#
# * **A Ball:** Like a standard Euclidean ball which contains all vectors with a norm less than a certain radius, the nuclear norm ball is the set of all matrices $X$ whose nuclear norm is less than or equal to a specified radius, $\tau$.
#
# Formally, the nuclear norm ball $C$ is the set:
# $$
# C = \{X \in \mathbb{R}^{m \times n} : \|X\|_* \le \tau \}
# $$
#
# #### 2. Why It's Crucial for Matrix Completion
#
# The core goal of Matrix Completion is to find a **low-rank** matrix that fits the observed data.  The rank of a matrix is the number of non-zero singular values. However, directly constraining the rank (e.g., $\text{rank}(X) \le \delta$) results in a non-convex, computationally intractable optimization problem.
#
# This is where the nuclear norm becomes essential. It serves as a **convex relaxation** for the rank function.  The intuition comes from a powerful analogy with vectors and sparsity:
#
# * **For Vectors (Sparsity):** In problems like LASSO, the **$l_1$ norm** ($\|\mathbf{v}\|_1 = \sum_i |v_i|$) is used as a penalty or constraint. It is well-known that minimizing the $l_1$ norm encourages solutions where many vector components are exactly zero, thus enforcing **sparsity**.
#
# * **For Matrices (Low-Rank):** The **nuclear norm** is the matrix equivalent of the $l_1$ norm. By minimizing the sum of singular values, it encourages solutions where many singular values are zero. This enforces **low-rankness**.
#
# Therefore, by constraining our solution $X$ to lie within a nuclear norm ball ($\|X\|_* \le \tau$), we are using a computationally feasible method to enforce the underlying assumption that the matrix we are looking for is low-rank.
#
# #### 3. The Connection to the Frank-Wolfe Algorithm
#
# The Frank-Wolfe algorithm is exceptionally well-suited for optimizing over the nuclear norm ball due to its geometric properties.
#
# * **The "Atoms" are Rank-1 Matrices:** The extreme points (the "corners" or "atoms") of the nuclear norm ball are all **rank-1 matrices**.  Specifically, the feasible set $C$ is the convex hull of all rank-1 matrices with a nuclear norm of $\tau$.
#
# * **The LMO Finds the Best Rank-1 Matrix:** At each iteration, the Frank-Wolfe Linear Minimization Oracle (LMO) solves for the atom that best aligns with the negative gradient. For this problem, this means the LMO finds the optimal **rank-1 matrix** to move towards.
#
# * **Frank-Wolfe Naturally Builds a Low-Rank Solution:** Because the algorithm constructs its solution as a convex combination of the atoms it has found, the resulting matrix is inherently a sum of a few rank-1 matrices. This means the solution produced by Frank-Wolfe is naturally **low-rank**, perfectly aligning with the goal of the Matrix Completion problem.

# %% [markdown]
# ## Python implementation
# Let's translate the theory into code. We will create a modular structure to easily assemble the three algorithms.

# %%
# Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# Import modules
from functions import MatrixCompletionProblem, accuracy_spectral
from algorithms import unified_frank_wolfe_solver
from data_loading import load_movielens, load_jester, load_steam
# Plotting style
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ## Data Selection and Preparation
# Three datasets:
# 1. MovieLens 100k
# 2. Jester Dataset 4
# 3. Steam

# %% [markdown]
# ## 1) MovieLens Dataset

# %% [markdown]
# ### Running Experiments and Analyzing Results

# %%
## 1) Load the MovieLens dataset
train_data_movie, test_data_movie = load_movielens(subset_percent_cols=1, subset_percent_rows=1)

# %%
train_data_movie.shape
# Out:
# (943, 1682)

# %%
test_data_movie.shape
# Out:
# (943, 1682)

# %%
# Instantiate the problem with the training data
mc_problem = MatrixCompletionProblem(train_data_movie)
TAU = 5000.0
MAX_ITER = 400
results_movie = {}

# %%
# Define all experiments by combining variants and stepsize strategies
experiments_movie_1 = [
    {'variant': 'classic', 'stepsize': 'exact', 'label': 'Classic FW (Exact LS)'},
    {'variant': 'away_step', 'stepsize': 'exact', 'label': 'Away-Step FW (Exact LS)'},
    {'variant': 'pairwise', 'stepsize': 'exact', 'label': 'Pairwise FW (Exact LS)'},
]
# Run experiments
for exp in experiments_movie_1:
    start_time = time.time()
    solution_X, history = unified_frank_wolfe_solver(
        problem=mc_problem, tau=TAU, max_iter=MAX_ITER,
        variant=exp['variant'], stepsize=exp['stepsize']
    )
    end_time = time.time()
    results_movie[exp['label']] = {"solution": solution_X, "history": history, "time": end_time - start_time}
# Out:
# Starting Frank-Wolfe Solver... selected classic variant
# Iteration 0, Objective: 28776.0625
# Iteration 10, Objective: 3865.5310
# Iteration 20, Objective: 2868.9738
# Iteration 30, Objective: 2298.2319
# Iteration 40, Objective: 1866.2236
# Iteration 50, Objective: 1548.4873
# Iteration 60, Objective: 1290.1519
# Iteration 70, Objective: 1084.1295
# Iteration 80, Objective: 906.0359
# Iteration 90, Objective: 776.7557
# Iteration 100, Objective: 670.7632
# Iteration 110, Objective: 569.9689
# Iteration 120, Objective: 489.2198
# Iteration 130, Objective: 409.7752
# Iteration 140, Objective: 354.2139
# Iteration 150, Objective: 308.1203
# Iteration 160, Objective: 267.9457
# Iteration 170, Objective: 231.1356
# Iteration 180, Objective: 199.5497
# Iteration 190, Objective: 176.5142
# Iteration 200, Objective: 152.4357
# Iteration 210, Objective: 136.2611
# Iteration 220, Objective: 121.9079
# Iteration 230, Objective: 108.0855
# Iteration 240, Objective: 95.2121
# ...

# %%
experiments_movie_2 = [
    {'variant': 'classic', 'stepsize': 'diminishing', 'label': 'Classic FW (Diminishing)'},
    {'variant': 'away_step', 'stepsize': 'diminishing', 'label': 'Away-Step FW (Diminishing)'},
    {'variant': 'pairwise', 'stepsize': 'diminishing', 'label': 'Pairwise FW (Diminishing)'},
]
# Run experiments
for exp in experiments_movie_2:
    start_time = time.time()
    solution_X, history = unified_frank_wolfe_solver(
        problem=mc_problem, tau=TAU, max_iter=MAX_ITER,
        variant=exp['variant'], stepsize=exp['stepsize']
    )
    end_time = time.time()
    results_movie[exp['label']] = {"solution": solution_X, "history": history, "time": end_time - start_time}
# Out:
# Starting Frank-Wolfe Solver... selected classic variant
# Iteration 0, Objective: 28776.0625
# Iteration 10, Objective: 262872.1913
# Iteration 20, Objective: 89468.7014
# Iteration 30, Objective: 55688.3015
# Iteration 40, Objective: 43552.5690
# Iteration 50, Objective: 37807.6149
# Iteration 60, Objective: 34609.3944
# Iteration 70, Objective: 17991.0183
# Iteration 80, Objective: 18800.8642
# Iteration 90, Objective: 19719.4399
# Iteration 100, Objective: 15535.1920
# Iteration 110, Objective: 16482.6881
# Iteration 120, Objective: 11569.3398
# Iteration 130, Objective: 12620.3494
# Iteration 140, Objective: 8108.0362
# Iteration 150, Objective: 9058.3502
# Iteration 160, Objective: 10010.9355
# Iteration 170, Objective: 10899.1059
# Iteration 180, Objective: 5588.2795
# Iteration 190, Objective: 6087.1478
# Iteration 200, Objective: 6518.8125
# Iteration 210, Objective: 6270.3214
# Iteration 220, Objective: 6639.1768
# Iteration 230, Objective: 6873.2218
# ...

# %%
experiments_movie_3 = [
    {'variant': 'classic', 'stepsize': 'armijo', 'label': 'Classic FW (Armijo)'},
    {'variant': 'away_step', 'stepsize': 'armijo', 'label': 'Away-Step FW (Armijo)'},
    {'variant': 'pairwise', 'stepsize': 'armijo', 'label': 'Pairwise FW (Armijo)'}
]
# Run experiments
for exp in experiments_movie_3:
    start_time = time.time()
    solution_X, history = unified_frank_wolfe_solver(
        problem=mc_problem, tau=TAU, max_iter=MAX_ITER,
        variant=exp['variant'], stepsize=exp['stepsize']
    )
    end_time = time.time()
    results_movie[exp['label']] = {"solution": solution_X, "history": history, "time": end_time - start_time}
# Out:
# Starting Frank-Wolfe Solver... selected classic variant
# Iteration 0, Objective: 28776.0625
# Iteration 10, Objective: 6812.5740
# Iteration 20, Objective: 4241.0124
# Iteration 30, Objective: 3553.0086
# Iteration 40, Objective: 3052.6431
# Iteration 50, Objective: 2880.5895
# Iteration 60, Objective: 2695.2959
# Iteration 70, Objective: 2635.3161
# Iteration 80, Objective: 2444.4780
# Iteration 90, Objective: 2358.5725
# Iteration 100, Objective: 2184.4830
# Iteration 110, Objective: 2044.9066
# Iteration 120, Objective: 1918.5153
# Iteration 130, Objective: 1784.4121
# Iteration 140, Objective: 1698.4638
# Iteration 150, Objective: 1602.0274
# Iteration 160, Objective: 1527.7698
# Iteration 170, Objective: 1450.3207
# Iteration 180, Objective: 1382.2204
# Iteration 190, Objective: 1317.6434
# Iteration 200, Objective: 1254.7402
# Iteration 210, Objective: 1213.3205
# Iteration 220, Objective: 1164.5662
# Iteration 230, Objective: 1111.5143
# Iteration 240, Objective: 1090.3461
# ...

# %% [markdown]
# ### Plot convergence

# %%
# Plotting the results
plt.figure(figsize=(14, 8))
for label, result in results_movie.items():
    plt.plot(result['history'], label=f"{label} (time: {result['time']:.2f}s)", lw=2.5, alpha=0.8)

plt.xlabel("Iteration", fontsize=14)
plt.ylabel("Objective Function (Training MSE)", fontsize=14)
plt.title("Convergence of Frank-Wolfe Variants and Stepsizes", fontsize=16)
plt.legend(fontsize=12)
plt.grid(True, which='both', linestyle='--')
plt.yscale('log')
plt.xlim(0, MAX_ITER)
plt.show()

# %% [markdown]
# ### Analyze Results and Evaluate on Test Set

# %%
# Prepare the summary of results
summary_data_movie = []
test_problem = MatrixCompletionProblem(test_data_movie)
num_test_ratings = len(test_data_movie.data)

for label, result in results_movie.items():
    final_train_error = result['history'][-1] if result['history'] else 'N/A'
    test_mse = test_problem.objective_function(result['solution'])
    test_rmse = np.sqrt(test_mse / num_test_ratings) if num_test_ratings > 0 else 0
    # include spectral accuracy as well
    spectral_accuracy = accuracy_spectral(test_problem, result['solution'])

    summary_data_movie.append({
        "Algorithm": label,
        "Final Training MSE": final_train_error,
        "Spectral Accuracy": spectral_accuracy,
        "Test RMSE": test_rmse,
        "Time (s)": result['time']
    })

summary_df_movie = pd.DataFrame(summary_data_movie)
print("\n--- Experiment on MovieLens Dataset Summary ---")
print(summary_df_movie.to_string(index=False))
# Out:
# --- Experiment on MovieLens Dataset Summary ---
#                  Algorithm  Final Training MSE  Spectral Accuracy  Test RMSE    Time (s)
#      Classic FW (Exact LS)           14.429872           9.398930   0.268211   66.605660
#    Away-Step FW (Exact LS)           13.962173          11.199151   0.275147  558.898992
#     Pairwise FW (Exact LS)           90.494120           6.398140   0.236266 1839.818866
#   Classic FW (Diminishing)         3490.730652          22.109855   0.308367   31.990153
# Away-Step FW (Diminishing)         4190.489068          13.714528   0.292950  205.954458
#  Pairwise FW (Diminishing)         4070.163872          25.845921   0.309402  633.621297
#        Classic FW (Armijo)          531.737562           8.513732   0.253148  386.735415
#      Away-Step FW (Armijo)          653.377915          12.637554   0.268209  781.018863
#       Pairwise FW (Armijo)          706.221794           7.368422   0.245083 1628.544981

# %% [markdown]
# ## 2) Jester 4 Dataset

# %% [markdown]
# ### Running Experiments and Analyzing Results

# %%
## 2) Load the Jester dataset
train_data_jester, test_data_jester = load_jester(subset_percent_cols=1.0, subset_percent_rows=0.25)

# %%
train_data_jester.shape
# Out:
# (1924, 158)

# %%
test_data_jester.shape
# Out:
# (1924, 158)

# %%
# Instantiate the problem with the training data
mc_problem = MatrixCompletionProblem(train_data_jester)
TAU = 5000.0
MAX_ITER = 400
results_jester = {}

# %%
# Define all experiments by combining variants and stepsize strategies
experiments_jester_1 = [
    {'variant': 'classic', 'stepsize': 'exact', 'label': 'Classic FW (Exact LS)'},
    {'variant': 'away_step', 'stepsize': 'exact', 'label': 'Away-Step FW (Exact LS)'},
    {'variant': 'pairwise', 'stepsize': 'exact', 'label': 'Pairwise FW (Exact LS)'},
]

# Run experiments
for exp in experiments_jester_1:
    start_time = time.time()
    solution_X, history = unified_frank_wolfe_solver(
        problem=mc_problem, tau=TAU, max_iter=MAX_ITER,
        variant=exp['variant'], stepsize=exp['stepsize']
    )
    end_time = time.time()
    results_jester[exp['label']] = {"solution": solution_X, "history": history, "time": end_time - start_time}
# Out:
# Starting Frank-Wolfe Solver... selected classic variant
# Iteration 0, Objective: 74041.4704
# Iteration 10, Objective: 79.9495
# Iteration 20, Objective: 52.1731
# Iteration 30, Objective: 36.2629
# Iteration 40, Objective: 25.8489
# Iteration 50, Objective: 18.5026
# Iteration 60, Objective: 13.2890
# Iteration 70, Objective: 9.5692
# Iteration 80, Objective: 6.9257
# Iteration 90, Objective: 5.0196
# Iteration 100, Objective: 3.6441
# Iteration 110, Objective: 2.6548
# Iteration 120, Objective: 1.9381
# Iteration 130, Objective: 1.4232
# Iteration 140, Objective: 1.0507
# Iteration 150, Objective: 0.7778
# Iteration 160, Objective: 0.5786
# Iteration 170, Objective: 0.4328
# Iteration 180, Objective: 0.3257
# Iteration 190, Objective: 0.2470
# Iteration 200, Objective: 0.1892
# Iteration 210, Objective: 0.1446
# Iteration 220, Objective: 0.1109
# Iteration 230, Objective: 0.0850
# Iteration 240, Objective: 0.0651
# Iteration 250, Objective: 0.0501
# ...

# %%
experiments_jester_2 = [
    {'variant': 'classic', 'stepsize': 'diminishing', 'label': 'Classic FW (Diminishing)'},
    {'variant': 'away_step', 'stepsize': 'diminishing', 'label': 'Away-Step FW (Diminishing)'},
    {'variant': 'pairwise', 'stepsize': 'diminishing', 'label': 'Pairwise FW (Diminishing)'},
]
# Run experiments
for exp in experiments_jester_2:
    start_time = time.time()
    solution_X, history = unified_frank_wolfe_solver(
        problem=mc_problem, tau=TAU, max_iter=MAX_ITER,
        variant=exp['variant'], stepsize=exp['stepsize']
    )
    end_time = time.time()
    results_jester[exp['label']] = {"solution": solution_X, "history": history, "time": end_time - start_time}
# Out:
# Starting Frank-Wolfe Solver... selected classic variant
# Iteration 0, Objective: 74041.4704
# Iteration 10, Objective: 371307.3664
# Iteration 20, Objective: 119719.7617
# Iteration 30, Objective: 64522.8335
# Iteration 40, Objective: 11095.7240
# Iteration 50, Objective: 14012.9189
# Iteration 60, Objective: 13068.2658
# Iteration 70, Objective: 3432.4156
# Iteration 80, Objective: 6972.2543
# Iteration 90, Objective: 5262.7287
# Iteration 100, Objective: 2943.6477
# Iteration 110, Objective: 4039.8945
# Iteration 120, Objective: 3688.1063
# Iteration 130, Objective: 2434.8924
# Iteration 140, Objective: 2546.8790
# Iteration 150, Objective: 1230.6720
# Iteration 160, Objective: 2006.7857
# Iteration 170, Objective: 1493.4929
# Iteration 180, Objective: 1062.0941
# Iteration 190, Objective: 1828.3491
# Iteration 200, Objective: 634.9832
# Iteration 210, Objective: 1189.5631
# Iteration 220, Objective: 431.3997
# Iteration 230, Objective: 661.8283
# ...

# %%
experiments_jester_3 = [
    {'variant': 'classic', 'stepsize': 'armijo', 'label': 'Classic FW (Armijo)'},
    {'variant': 'away_step', 'stepsize': 'armijo', 'label': 'Away-Step FW (Armijo)'},
    {'variant': 'pairwise', 'stepsize': 'armijo', 'label': 'Pairwise FW (Armijo)'}
]
# Run experiments
for exp in experiments_jester_3:
    start_time = time.time()
    solution_X, history = unified_frank_wolfe_solver(
        problem=mc_problem, tau=TAU, max_iter=MAX_ITER,
        variant=exp['variant'], stepsize=exp['stepsize']
    )
    end_time = time.time()
    results_jester[exp['label']] = {"solution": solution_X, "history": history, "time": end_time - start_time}
# Out:
# Starting Frank-Wolfe Solver... selected classic variant
# Iteration 0, Objective: 74041.4704
# Iteration 10, Objective: 3936.7050
# Iteration 20, Objective: 269.5343
# Iteration 30, Objective: 162.7101
# Iteration 40, Objective: 119.4292
# Iteration 50, Objective: 95.8966
# Iteration 60, Objective: 81.6652
# Iteration 70, Objective: 69.3642
# Iteration 80, Objective: 60.1443
# Iteration 90, Objective: 54.3405
# Iteration 100, Objective: 47.0294
# Iteration 110, Objective: 42.1254
# Iteration 120, Objective: 38.1112
# Iteration 130, Objective: 33.7577
# Iteration 140, Objective: 30.2831
# Iteration 150, Objective: 27.8833
# Iteration 160, Objective: 26.3441
# Iteration 170, Objective: 24.5714
# Iteration 180, Objective: 22.3762
# Iteration 190, Objective: 20.4879
# Iteration 200, Objective: 18.2249
# Iteration 210, Objective: 16.6481
# Iteration 220, Objective: 14.9948
# Iteration 230, Objective: 13.8256
# Iteration 240, Objective: 12.6573
# Iteration 250, Objective: 12.0157
# ...

# %% [markdown]
# ### Plot convergence

# %%
# Plotting the results
plt.figure(figsize=(14, 8))
for label, result in results_jester.items():
    plt.plot(result['history'], label=f"{label} (time: {result['time']:.2f}s)", lw=2.5, alpha=0.8)

plt.xlabel("Iteration", fontsize=14)
plt.ylabel("Objective Function (Training MSE)", fontsize=14)
plt.title("Convergence of Frank-Wolfe Variants and Stepsizes", fontsize=16)
plt.legend(fontsize=12)
plt.grid(True, which='both', linestyle='--')
plt.yscale('log')
plt.xlim(0, MAX_ITER)
plt.show()

# %% [markdown]
# ### Analyze Results and Evaluate on Test Set

# %%
# Prepare the summary of results
summary_data_jester = []
test_problem = MatrixCompletionProblem(test_data_jester)
num_test_ratings = len(test_data_jester.data)

for label, result in results_jester.items():
    final_train_error = result['history'][-1] if result['history'] else 'N/A'
    test_mse = test_problem.objective_function(result['solution'])
    test_rmse = np.sqrt(test_mse / num_test_ratings) if num_test_ratings > 0 else 0
    # include spectral accuracy as well
    spectral_accuracy = accuracy_spectral(test_problem, result['solution'])

    summary_data_jester.append({
        "Algorithm": label,
        "Final Training MSE": final_train_error,
        "Spectral Accuracy": spectral_accuracy,
        "Test RMSE": test_rmse,
        "Time (s)": result['time']
    })

summary_df_jester = pd.DataFrame(summary_data_jester)
print("\n--- Experiment on Jester 4 Dataset Summary ---")
print(summary_df_jester.to_string(index=False))
# Out:
# --- Experiment on Jester 4 Dataset Summary ---
#                  Algorithm  Final Training MSE  Spectral Accuracy  Test RMSE   Time (s)
#      Classic FW (Exact LS)            0.001008           2.649131   0.029519  14.545547
#    Away-Step FW (Exact LS)            0.001205           2.643919   0.029746 103.013167
#     Pairwise FW (Exact LS)            0.006160           2.657452   0.026536 368.451884
#   Classic FW (Diminishing)          389.303968          30.645056   0.094378   7.201716
# Away-Step FW (Diminishing)          331.416015          20.344156   0.086720  37.215572
#  Pairwise FW (Diminishing)          660.234002          13.414720   0.052989 133.549353
#        Classic FW (Armijo)            3.717211           7.081737   0.054436  80.352358
#      Away-Step FW (Armijo)            5.092371          19.436207   0.082138 162.700399
#       Pairwise FW (Armijo)            0.847369           2.669231   0.029355 336.860753

# %% [markdown]
# ## 3) Steam Dataset

# %% [markdown]
# ### Running Experiments and Analyzing Results

# %%
## 3) Load the Steam dataset
train_data_steam, test_data_steam = load_steam(subset_percent_cols=0.4, subset_percent_rows=0.2)

# %%
train_data_steam.shape
# Out:
# (1190, 850)

# %%
test_data_steam.shape
# Out:
# (1190, 850)

# %%
# Instantiate the problem with the training data
mc_problem = MatrixCompletionProblem(train_data_steam)
TAU = 5000.0
MAX_ITER = 400
results_steam = {}

# %%
# Define all experiments by combining variants and stepsize strategies
experiments_steam_1 = [
    {'variant': 'classic', 'stepsize': 'exact', 'label': 'Classic FW (Exact LS)'},
    {'variant': 'away_step', 'stepsize': 'exact', 'label': 'Away-Step FW (Exact LS)'},
    {'variant': 'pairwise', 'stepsize': 'exact', 'label': 'Pairwise FW (Exact LS)'},
]
# Run experiments
for exp in experiments_steam_1:
    start_time = time.time()
    solution_X, history = unified_frank_wolfe_solver(
        problem=mc_problem, tau=TAU, max_iter=MAX_ITER,
        variant=exp['variant'], stepsize=exp['stepsize']
    )
    end_time = time.time()
    results_steam[exp['label']] = {"solution": solution_X, "history": history, "time": end_time - start_time}
# Out:
# Starting Frank-Wolfe Solver... selected classic variant
# Iteration 0, Objective: 4.2690
# Iteration 10, Objective: 0.2861
# Iteration 20, Objective: 0.0982
# Iteration 30, Objective: 0.0511
# Iteration 40, Objective: 0.0285
# Iteration 50, Objective: 0.0156
# Iteration 60, Objective: 0.0089
# Iteration 70, Objective: 0.0057
# Iteration 80, Objective: 0.0039
# Iteration 90, Objective: 0.0025
# Iteration 100, Objective: 0.0018
# Iteration 110, Objective: 0.0012
# Iteration 120, Objective: 0.0010
# Iteration 130, Objective: 0.0007
# Iteration 140, Objective: 0.0005
# Iteration 150, Objective: 0.0003
# Iteration 160, Objective: 0.0003
# Iteration 170, Objective: 0.0002
# Iteration 180, Objective: 0.0002
# Iteration 190, Objective: 0.0001
# Iteration 200, Objective: 0.0001
# Iteration 210, Objective: 0.0001
# Iteration 220, Objective: 0.0000
# Iteration 230, Objective: 0.0000
# Iteration 240, Objective: 0.0000
# Iteration 250, Objective: 0.0000
# Iteration 260, Objective: 0.0000
# ...

# %%
experiments_steam_2 = [
    {'variant': 'classic', 'stepsize': 'diminishing', 'label': 'Classic FW (Diminishing)'},
    {'variant': 'away_step', 'stepsize': 'diminishing', 'label': 'Away-Step FW (Diminishing)'},
    {'variant': 'pairwise', 'stepsize': 'diminishing', 'label': 'Pairwise FW (Diminishing)'},
]
# Run experiments
for exp in experiments_steam_2:
    start_time = time.time()
    solution_X, history = unified_frank_wolfe_solver(
        problem=mc_problem, tau=TAU, max_iter=MAX_ITER,
        variant=exp['variant'], stepsize=exp['stepsize']
    )
    end_time = time.time()
    results_steam[exp['label']] = {"solution": solution_X, "history": history, "time": end_time - start_time}
# Out:
# Starting Frank-Wolfe Solver... selected classic variant
# Iteration 0, Objective: 4.2690
# Iteration 10, Objective: 208022.2598
# Iteration 20, Objective: 57398.1964
# Iteration 30, Objective: 26491.8943
# Iteration 40, Objective: 15232.8981
# Iteration 50, Objective: 9902.1440
# Iteration 60, Objective: 6961.9639
# Iteration 70, Objective: 5168.8958
# Iteration 80, Objective: 3994.5508
# Iteration 90, Objective: 3183.3089
# Iteration 100, Objective: 2599.2149
# Iteration 110, Objective: 2164.5215
# Iteration 120, Objective: 1832.1435
# Iteration 130, Objective: 1572.2053
# Iteration 140, Objective: 1365.0056
# Iteration 150, Objective: 1197.1227
# Iteration 160, Objective: 1059.1554
# Iteration 170, Objective: 944.3587
# Iteration 180, Objective: 847.7907
# Iteration 190, Objective: 765.7630
# Iteration 200, Objective: 695.4774
# Iteration 210, Objective: 634.7795
# Iteration 220, Objective: 581.9885
# Iteration 230, Objective: 535.7777
# Iteration 240, Objective: 495.0883
# ...

# %% [markdown]
# ### Running Experiments and Analyzing Results

# %%
experiments_steam_3 = [
    {'variant': 'classic', 'stepsize': 'armijo', 'label': 'Classic FW (Armijo)'},
    {'variant': 'away_step', 'stepsize': 'armijo', 'label': 'Away-Step FW (Armijo)'},
    {'variant': 'pairwise', 'stepsize': 'armijo', 'label': 'Pairwise FW (Armijo)'}
]
# Run experiments
for exp in experiments_steam_3:
    start_time = time.time()
    solution_X, history = unified_frank_wolfe_solver(
        problem=mc_problem, tau=TAU, max_iter=MAX_ITER,
        variant=exp['variant'], stepsize=exp['stepsize']
    )
    end_time = time.time()
    results_steam[exp['label']] = {"solution": solution_X, "history": history, "time": end_time - start_time}
# Out:
# Starting Frank-Wolfe Solver... selected classic variant
# Iteration 0, Objective: 4.2690
# Iteration 10, Objective: 1.5065
# Iteration 20, Objective: 0.9452
# Iteration 30, Objective: 0.6165
# Iteration 40, Objective: 0.4386
# Iteration 50, Objective: 0.3075
# Iteration 60, Objective: 0.2331
# Iteration 70, Objective: 0.2177
# Iteration 80, Objective: 0.1808
# Iteration 90, Objective: 0.1502
# Iteration 100, Objective: 0.1229
# Iteration 110, Objective: 0.0970
# Iteration 120, Objective: 0.0821
# Iteration 130, Objective: 0.0715
# Iteration 140, Objective: 0.0598
# Iteration 150, Objective: 0.0506
# Iteration 160, Objective: 0.0455
# Iteration 170, Objective: 0.0451
# Iteration 180, Objective: 0.0449
# Iteration 190, Objective: 0.0444
# Iteration 200, Objective: 0.0443
# Iteration 210, Objective: 0.0442
# Iteration 220, Objective: 0.0406
# Iteration 230, Objective: 0.0380
# Iteration 240, Objective: 0.0334
# Iteration 250, Objective: 0.0291
# Iteration 260, Objective: 0.0252
# ...

# %% [markdown]
# ### Plot convergence

# %%
# Plotting the results
plt.figure(figsize=(14, 8))
for label, result in results_steam.items():
    plt.plot(result['history'], label=f"{label} (time: {result['time']:.2f}s)", lw=2.5, alpha=0.8)

plt.xlabel("Iteration", fontsize=14)
plt.ylabel("Objective Function (Training MSE)", fontsize=14)
plt.title("Convergence of Frank-Wolfe Variants and Stepsizes", fontsize=16)
plt.legend(fontsize=12)
plt.grid(True, which='both', linestyle='--')
plt.yscale('log')
plt.xlim(0, MAX_ITER)
plt.show()

# %% [markdown]
# ### Analyze Results and Evaluate on Test Set

# %%
# Prepare the summary of results
summary_data_steam = []
test_problem = MatrixCompletionProblem(test_data_steam)
num_test_ratings = len(test_data_steam.data)

for label, result in results_steam.items():
    final_train_error = result['history'][-1] if result['history'] else 'N/A'
    test_mse = test_problem.objective_function(result['solution'])
    test_rmse = np.sqrt(test_mse / num_test_ratings) if num_test_ratings > 0 else 0
    # include spectral accuracy as well
    spectral_accuracy = accuracy_spectral(test_problem, result['solution'])

    summary_data_steam.append({
        "Algorithm": label,
        "Final Training MSE": final_train_error,
        "Spectral Accuracy": spectral_accuracy,
        "Test RMSE": test_rmse,
        "Time (s)": result['time']
    })
summary_df_steam = pd.DataFrame(summary_data_steam)
print("\n--- Experiment on Steam Dataset Summary ---")
print(summary_df_steam.to_string(index=False))
# Out:
# --- Experiment on Steam Dataset Summary ---
#                  Algorithm  Final Training MSE  Spectral Accuracy  Test RMSE    Time (s)
#      Classic FW (Exact LS)        1.942220e-07           1.525735   0.040470   43.136643
#    Away-Step FW (Exact LS)        4.332842e-07          15.290977   0.377906  362.681961
#     Pairwise FW (Exact LS)        3.661524e-04          13.652991   0.342011 1330.720806
#   Classic FW (Diminishing)        1.247952e+02           1.525127   0.040511   20.745574
# Away-Step FW (Diminishing)        1.977619e+02           1.525165   0.040511  342.727322
#  Pairwise FW (Diminishing)        6.471369e+02           6.081553   0.136043  484.960684
#        Classic FW (Armijo)        4.894713e-03           1.510903   0.043085  370.515742
#      Away-Step FW (Armijo)        1.273253e-02           1.401702   0.038800  685.382410
#       Pairwise FW (Armijo)        1.415628e-03           3.266851   0.073946 1403.172513

# %% [markdown]
# ## Variants Comparison

# %%
# Combine the summary data from all three experiments into a single DataFrame
summary_df_movie['Dataset'] = 'MovieLens'
summary_df_jester['Dataset'] = 'Jester'
summary_df_steam['Dataset'] = 'Steam'

combined_summary_df = pd.concat([summary_df_movie, summary_df_jester, summary_df_steam], ignore_index=True)

print("--- Combined Performance Summary Across All Datasets ---")
print(combined_summary_df[['Dataset', 'Algorithm', 'Spectral Accuracy', 'Test RMSE', 'Time (s)']].sort_values(by=['Dataset', 'Test RMSE']).to_string(index=False))


# Plotting the Comparisons

# Plot 1: Comparing Test RMSE across datasets
pivot_rmse = combined_summary_df.pivot(index='Algorithm', columns='Dataset', values='Test RMSE')
pivot_rmse.plot(kind='bar', figsize=(18, 8), width=0.8, alpha=0.8)
plt.title('Comparison of Test RMSE by Algorithm and Dataset', fontsize=16)
plt.xlabel('Algorithm', fontsize=14)
plt.ylabel('Test RMSE', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Dataset', fontsize=12)
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()

# Plot 2: Comparing Execution Time across datasets
pivot_time = combined_summary_df.pivot(index='Algorithm', columns='Dataset', values='Time (s)')
pivot_time.plot(kind='bar', figsize=(18, 8), width=0.8, alpha=0.8)
plt.title('Comparison of Execution Time by Algorithm and Dataset', fontsize=16)
plt.xlabel('Algorithm', fontsize=14)
plt.ylabel('Time (s)', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Dataset', fontsize=12)
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()

# plot 3: Comparing Spectral Accuracy across datasets
pivot_spectral = combined_summary_df.pivot(index='Algorithm', columns='Dataset', values='Spectral Accuracy')
pivot_spectral.plot(kind='bar', figsize=(18, 8), width=0.8, alpha=0.8)
plt.title('Comparison of Spectral Accuracy by Algorithm and Dataset', fontsize=16)
plt.xlabel('Algorithm', fontsize=14)
plt.ylabel('Spectral Accuracy', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Dataset', fontsize=12)
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()
# Out:
# --- Combined Performance Summary Across All Datasets ---
#   Dataset                  Algorithm  Spectral Accuracy  Test RMSE    Time (s)
#    Jester     Pairwise FW (Exact LS)           2.657452   0.026536  368.451884
#    Jester       Pairwise FW (Armijo)           2.669231   0.029355  336.860753
#    Jester      Classic FW (Exact LS)           2.649131   0.029519   14.545547
#    Jester    Away-Step FW (Exact LS)           2.643919   0.029746  103.013167
#    Jester  Pairwise FW (Diminishing)          13.414720   0.052989  133.549353
#    Jester        Classic FW (Armijo)           7.081737   0.054436   80.352358
#    Jester      Away-Step FW (Armijo)          19.436207   0.082138  162.700399
#    Jester Away-Step FW (Diminishing)          20.344156   0.086720   37.215572
#    Jester   Classic FW (Diminishing)          30.645056   0.094378    7.201716
# MovieLens     Pairwise FW (Exact LS)           6.398140   0.236266 1839.818866
# ...
